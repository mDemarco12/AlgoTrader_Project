# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Apple = yf.download("AAPL", start = "2010-01-01", end = "2021-01-01")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
Apple
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-01-04    7.622500    7.660714    7.585000    7.643214    6.478998
# 2010-01-05    7.664286    7.699643    7.616071    7.656429    6.490201
# 2010-01-06    7.656429    7.686786    7.526786    7.534643    6.386965
# 2010-01-07    7.562500    7.571429    7.466071    7.520714    6.375158
# 2010-01-08    7.510714    7.571429    7.466429    7.570714    6.417541
# ...                ...         ...         ...         ...         ...
# 2020-12-24  131.320007  133.460007  131.100006  131.970001  129.679733
# 2020-12-28  133.990005  137.339996  133.509995  136.690002  134.317810
# 2020-12-29  138.050003  138.789993  134.339996  134.869995  132.529388
# 2020-12-30  135.580002  135.990005  133.399994  133.720001  131.399338
# 2020-12-31  134.080002  134.740005  131.720001  132.690002  130.387238
#
#                Volume
# Date
# 2010-01-04  493729600
# 2010-01-05  601904800
# 2010-01-06  552160000
# ...

# %%
a =[1,2,3,5]
a
# Out:
# [1, 2, 3, 5]

# %%
ticker = ["SPY", "AAPL","KO"]

# %%
stocks = yf.download(ticker, start = "2010-01-01", end = "2021-01-01")
# Out:
# [*********************100%%**********************]  3 of 3 completed

# %%
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2769 entries, 2010-01-04 to 2020-12-31
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Adj Close, AAPL)  2769 non-null   float64
#  1   (Adj Close, KO)    2769 non-null   float64
#  2   (Adj Close, SPY)   2769 non-null   float64
#  3   (Close, AAPL)      2769 non-null   float64
#  4   (Close, KO)        2769 non-null   float64
#  5   (Close, SPY)       2769 non-null   float64
#  6   (High, AAPL)       2769 non-null   float64
#  7   (High, KO)         2769 non-null   float64
#  8   (High, SPY)        2769 non-null   float64
#  9   (Low, AAPL)        2769 non-null   float64
#  10  (Low, KO)          2769 non-null   float64
#  11  (Low, SPY)         2769 non-null   float64
#  12  (Open, AAPL)       2769 non-null   float64
#  13  (Open, KO)         2769 non-null   float64
#  14  (Open, SPY)        2769 non-null   float64
# ...

# %%
stocks.to_csv("stocks.csv")

# %%
stocks
# Out:
#              Adj Close                              Close             \
#                   AAPL         KO         SPY        AAPL         KO
# Date
# 2010-01-04    6.478998  18.498011   87.483200    7.643214  28.520000
# 2010-01-05    6.490201  18.274248   87.714760    7.656429  28.174999
# 2010-01-06    6.386965  18.267763   87.776535    7.534643  28.165001
# 2010-01-07    6.375158  18.222366   88.147072    7.520714  28.094999
# 2010-01-08    6.417541  17.885094   88.440414    7.570714  27.575001
# ...                ...        ...         ...         ...        ...
# 2020-12-24  129.679733  48.779102  354.399048  131.970001  53.439999
# 2020-12-28  134.317810  49.436310  357.443665  136.690002  54.160000
# 2020-12-29  132.529388  49.408932  356.761688  134.869995  54.130001
# 2020-12-30  131.399338  49.691887  357.270752  133.720001  54.439999
# 2020-12-31  130.387238  50.057007  359.086029  132.690002  54.840000
#
# ...

# %%
stocks = pd.read_csv("stocks.csv", header =[0,1],index_col =[0])
stocks
# Out:
#              Adj Close                              Close             \
#                   AAPL         KO         SPY        AAPL         KO
# Date
# 2010-01-04    6.478998  18.498011   87.483200    7.643214  28.520000
# 2010-01-05    6.490201  18.274248   87.714760    7.656429  28.174999
# 2010-01-06    6.386965  18.267763   87.776535    7.534643  28.165001
# 2010-01-07    6.375158  18.222366   88.147072    7.520714  28.094999
# 2010-01-08    6.417541  17.885094   88.440414    7.570714  27.575001
# ...                ...        ...         ...         ...        ...
# 2020-12-24  129.679733  48.779102  354.399048  131.970001  53.439999
# 2020-12-28  134.317810  49.436310  357.443665  136.690002  54.160000
# 2020-12-29  132.529388  49.408932  356.761688  134.869995  54.130001
# 2020-12-30  131.399338  49.691887  357.270752  133.720001  54.439999
# 2020-12-31  130.387238  50.057007  359.086029  132.690002  54.840000
#
# ...

# %%
stocks = pd.read_csv("stocks.csv", header =[0,1],index_col =[0], parse_dates=[0])
stocks
# Out:
#              Adj Close                              Close             \
#                   AAPL         KO         SPY        AAPL         KO
# Date
# 2010-01-04    6.478998  18.498011   87.483200    7.643214  28.520000
# 2010-01-05    6.490201  18.274248   87.714760    7.656429  28.174999
# 2010-01-06    6.386965  18.267763   87.776535    7.534643  28.165001
# 2010-01-07    6.375158  18.222366   88.147072    7.520714  28.094999
# 2010-01-08    6.417541  17.885094   88.440414    7.570714  27.575001
# ...                ...        ...         ...         ...        ...
# 2020-12-24  129.679733  48.779102  354.399048  131.970001  53.439999
# 2020-12-28  134.317810  49.436310  357.443665  136.690002  54.160000
# 2020-12-29  132.529388  49.408932  356.761688  134.869995  54.130001
# 2020-12-30  131.399338  49.691887  357.270752  133.720001  54.439999
# 2020-12-31  130.387238  50.057007  359.086029  132.690002  54.840000
#
# ...

# %%
stocks.columns
# Out:
# MultiIndex([('Adj Close', 'AAPL'),
#             ('Adj Close',   'KO'),
#             ('Adj Close',  'SPY'),
#             (    'Close', 'AAPL'),
#             (    'Close',   'KO'),
#             (    'Close',  'SPY'),
#             (     'High', 'AAPL'),
#             (     'High',   'KO'),
#             (     'High',  'SPY'),
#             (      'Low', 'AAPL'),
#             (      'Low',   'KO'),
#             (      'Low',  'SPY'),
#             (     'Open', 'AAPL'),
#             (     'Open',   'KO'),
#             (     'Open',  'SPY'),
#             (   'Volume', 'AAPL'),
#             (   'Volume',   'KO'),
#             (   'Volume',  'SPY')],
#            )

# %%
#convert multiIndex to one tuple
stocks.columns = stocks.columns.to_flat_index()

# %%
stocks.columns
# Out:
# Index([('Adj Close', 'AAPL'),   ('Adj Close', 'KO'),  ('Adj Close', 'SPY'),
#            ('Close', 'AAPL'),       ('Close', 'KO'),      ('Close', 'SPY'),
#             ('High', 'AAPL'),        ('High', 'KO'),       ('High', 'SPY'),
#              ('Low', 'AAPL'),         ('Low', 'KO'),        ('Low', 'SPY'),
#             ('Open', 'AAPL'),        ('Open', 'KO'),       ('Open', 'SPY'),
#           ('Volume', 'AAPL'),      ('Volume', 'KO'),     ('Volume', 'SPY')],
#       dtype='object')

# %%
stocks
# Out:
#             (Adj Close, AAPL)  (Adj Close, KO)  (Adj Close, SPY)  \
# Date
# 2010-01-04           6.478998        18.498011         87.483200
# 2010-01-05           6.490201        18.274248         87.714760
# 2010-01-06           6.386965        18.267763         87.776535
# 2010-01-07           6.375158        18.222366         88.147072
# 2010-01-08           6.417541        17.885094         88.440414
# ...                       ...              ...               ...
# 2020-12-24         129.679733        48.779102        354.399048
# 2020-12-28         134.317810        49.436310        357.443665
# 2020-12-29         132.529388        49.408932        356.761688
# 2020-12-30         131.399338        49.691887        357.270752
# 2020-12-31         130.387238        50.057007        359.086029
#
#             (Close, AAPL)  (Close, KO)  (Close, SPY)  (High, AAPL)  \
# Date
# 2010-01-04       7.643214    28.520000    113.330002      7.660714
# ...

# %%
stocks.columns = pd.MultiIndex.from_tuples(stocks.columns)
stocks
# Out:
#              Adj Close                              Close             \
#                   AAPL         KO         SPY        AAPL         KO
# Date
# 2010-01-04    6.478998  18.498011   87.483200    7.643214  28.520000
# 2010-01-05    6.490201  18.274248   87.714760    7.656429  28.174999
# 2010-01-06    6.386965  18.267763   87.776535    7.534643  28.165001
# 2010-01-07    6.375158  18.222366   88.147072    7.520714  28.094999
# 2010-01-08    6.417541  17.885094   88.440414    7.570714  27.575001
# ...                ...        ...         ...         ...        ...
# 2020-12-24  129.679733  48.779102  354.399048  131.970001  53.439999
# 2020-12-28  134.317810  49.436310  357.443665  136.690002  54.160000
# 2020-12-29  132.529388  49.408932  356.761688  134.869995  54.130001
# 2020-12-30  131.399338  49.691887  357.270752  133.720001  54.439999
# 2020-12-31  130.387238  50.057007  359.086029  132.690002  54.840000
#
# ...

# %%
stocks.columns
# Out:
# MultiIndex([('Adj Close', 'AAPL'),
#             ('Adj Close',   'KO'),
#             ('Adj Close',  'SPY'),
#             (    'Close', 'AAPL'),
#             (    'Close',   'KO'),
#             (    'Close',  'SPY'),
#             (     'High', 'AAPL'),
#             (     'High',   'KO'),
#             (     'High',  'SPY'),
#             (      'Low', 'AAPL'),
#             (      'Low',   'KO'),
#             (      'Low',  'SPY'),
#             (     'Open', 'AAPL'),
#             (     'Open',   'KO'),
#             (     'Open',  'SPY'),
#             (   'Volume', 'AAPL'),
#             (   'Volume',   'KO'),
#             (   'Volume',  'SPY')],
#            )

# %%
stocks.describe()
# Out:
#          Adj Close                                  Close               \
#               AAPL           KO          SPY         AAPL           KO
# count  2769.000000  2769.000000  2769.000000  2769.000000  2769.000000
# mean     31.562566    32.208758   182.790482    33.777537    41.320121
# std      24.614793     8.183724    69.986182    24.572747     6.808527
# min       5.814176    16.373816    79.593353     6.858929    25.014999
# 25%      15.201327    26.605549   115.347031    17.484285    37.660000
# 50%      24.549244    31.768909   176.694580    26.987499    41.759998
# 75%      40.931633    37.628517   242.913635    43.007500    45.549999
# max     134.317810    53.069550   359.086029   136.690002    60.130001
#
#                            High                                    Low  \
#                SPY         AAPL           KO          SPY         AAPL
# count  2769.000000  2769.000000  2769.000000  2769.000000  2769.000000
# ...

# %%
stocks.loc[:,"Close"]
# Out:
#                   AAPL         KO         SPY
# Date
# 2010-01-04    7.643214  28.520000  113.330002
# 2010-01-05    7.656429  28.174999  113.629997
# 2010-01-06    7.534643  28.165001  113.709999
# 2010-01-07    7.520714  28.094999  114.190002
# 2010-01-08    7.570714  27.575001  114.570000
# ...                ...        ...         ...
# 2020-12-24  131.970001  53.439999  369.000000
# 2020-12-28  136.690002  54.160000  372.170013
# 2020-12-29  134.869995  54.130001  371.459991
# 2020-12-30  133.720001  54.439999  371.989990
# 2020-12-31  132.690002  54.840000  373.880005
#
# [2769 rows x 3 columns]

# %%
close = stocks.loc[:,"Close"]

# %%
close
# Out:
#                   AAPL         KO         SPY
# Date
# 2010-01-04    7.643214  28.520000  113.330002
# 2010-01-05    7.656429  28.174999  113.629997
# 2010-01-06    7.534643  28.165001  113.709999
# 2010-01-07    7.520714  28.094999  114.190002
# 2010-01-08    7.570714  27.575001  114.570000
# ...                ...        ...         ...
# 2020-12-24  131.970001  53.439999  369.000000
# 2020-12-28  136.690002  54.160000  372.170013
# 2020-12-29  134.869995  54.130001  371.459991
# 2020-12-30  133.720001  54.439999  371.989990
# 2020-12-31  132.690002  54.840000  373.880005
#
# [2769 rows x 3 columns]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use("seaborn")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/style/core.py:137, in use(style)
#     136 try:
# --> 137     style = _rc_params_in_file(style)
#     138 except OSError as err:
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/__init__.py:866, in _rc_params_in_file(fname, transform, fail_on_error)
#     865 rc_temp = {}
# --> 866 with _open_file_or_url(fname) as fd:
#     867     try:
#
# File ~/anaconda3/lib/python3.11/contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/__init__.py:843, in _open_file_or_url(fname)
#     842 fname = os.path.expanduser(fname)
# --> 843 with open(fname, encoding='utf-8') as f:
#     844     yield f
#
# ...

# %%
close.plot(figsize=(15,8), fontsize=12)

# %%
close.plot(figsize=(15,8), fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
close.iloc[0,0]

# %%
close.AAPL

# %%
close.AAPL.div(close.iloc[0,0])

# %%
close.AAPL.div(close.iloc[0,0]).mul(100)

# %%
close.iloc[0]

# %%
close.div(close.iloc[0]).mul(100)

# %%
normClose =close.div(close.iloc[0]).mul(100)

# %%
normClose.plot(figsize=(15,8), fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
aapl= close.AAPL.copy().to_frame()

# %%
aapl

# %%
aapl.shift(periods=1)

# %%
aapl["lag1"]= aapl.shift(periods=1)

# %%
aapl

# %%
aapl.AAPL.sub(aapl.lag1)

# %%
aapl["Diff"]= aapl.AAPL.sub(aapl.lag1)

# %%
aapl

# %%
aapl.AAPL.div(aapl.lag1)

# %%
aapl["% Change"]= aapl.AAPL.div(aapl.lag1).sub(1).mul(100)

# %%
aapl

# %%
aapl["Diff2"]=aapl.AAPL.diff(periods=1)

# %%
aapl

# %%
aapl["% Change 2"]= aapl.AAPL.pct_change(periods=1).mul(100)

# %%
aapl

# %%
aapl

# %%
del aapl["% Change"]

# %%
aapl

# %%
aapl.rename(columns = {'% Change 2' : 'Change'}, inplace = True)

# %%
aapl

# %%
aapl.AAPL.resample("M").last()

# %%
aapl.AAPL.resample("BM").last()

# %%
aapl.AAPL.resample("BM").last().pct_change(periods=1).mul(100)

# %%
aapl

# %%
del aapl["Change"]

# %%
aapl

# %%
ret = aapl.pct_change().dropna()

# %%
ret

# %%
ret.plot(kind = "hist", figsize=(12,8), bins=100)
plt.show()

# %%
daily_mean_return = ret.mean()
daily_mean_return

# %%
var_daily = ret.var()
var_daily

# %%
std_daily= np.sqrt(var_daily)

# %%
var_daily

# %%
ret.std()

# %%
annual_mean_ret =daily_mean_return*252
annual_mean_ret

# %%
annual_var_return = var_daily*252
annual_var_return

# %%
annual_std_return=np.sqrt(annual_var_return)
annual_std_return

# %%
ret.std()*np.sqrt(252)

# %%
ticker = ["SPY", "AAPL","KO", "NVDA","AMD","CELH","TSLA"]

# %%
stocks

# %%
stocks = yf.download(ticker, start = "2010-01-01", end = "2021-01-01")

# %%
close = stocks.loc[:,"Close"].copy()

# %%
normClose=close.div(close.iloc[0]).mul(100)

# %%
normClose.plot(figsize=(15,8), fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
ret= close.pct_change().dropna()
ret.head()
# Out:
#                 AAPL        KO       SPY
# Date
# 2010-01-05  0.001729 -0.012097  0.002647
# 2010-01-06 -0.015906 -0.000355  0.000704
# 2010-01-07 -0.001849 -0.002485  0.004221
# 2010-01-08  0.006648 -0.018509  0.003328
# 2010-01-11 -0.008821  0.020308  0.001397

# %%
ret.describe().T
# Out:
#        count      mean       std       min       25%       50%       75%  \
# AAPL  2768.0  0.001191  0.017843 -0.128647 -0.007123  0.000903  0.010379
# KO    2768.0  0.000298  0.011088 -0.096725 -0.004698  0.000438  0.005706
# SPY   2768.0  0.000491  0.010909 -0.109424 -0.003532  0.000637  0.005421
#
#            max
# AAPL  0.119808
# KO    0.064796
# SPY   0.090603

# %%
ret.describe().T.loc[:,["mean","std"]]
# Out:
#           mean       std
# AAPL  0.001191  0.017843
# KO    0.000298  0.011088
# SPY   0.000491  0.010909

# %%
summary = ret.describe().T.loc[:,["mean","std"]]
summary
# Out:
#           mean       std
# AAPL  0.001191  0.017843
# KO    0.000298  0.011088
# SPY   0.000491  0.010909

# %%
summary["mean"] = summary["mean"]*252
summary["std"] = summary["std"]*np.sqrt(252)
summary
# Out:
#           mean       std
# AAPL  0.300134  0.283242
# KO    0.075091  0.176009
# SPY   0.123754  0.173170

# %%
summary.plot.scatter(x = "std", y = "mean", figsize= (12,8),s=50, fontsize=15)
for i in summary.index:
    plt.annotate(i,xy=(summary.loc[i,"std"]+0.002,summary.loc[i,"mean"]+0.002),size=15)
plt.xlabel("Annual risk(Standard Deviation)", fontsize=15)
plt.ylabel("Annual return", fontsize=15)
plt.title("Risk/Return",fontsize=25)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
##Correlation and Covariance

# %%
ret.cov()
# Out:
#           AAPL        KO       SPY
# AAPL  0.000318  0.000067  0.000128
# KO    0.000067  0.000123  0.000077
# SPY   0.000128  0.000077  0.000119

# %%
ret.corr()
# Out:
#           AAPL        KO       SPY
# AAPL  1.000000  0.339213  0.659557
# KO    0.339213  1.000000  0.639324
# SPY   0.659557  0.639324  1.000000

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.4)
sns.heatmap(ret.corr(),cmap="Reds",annot=True,annot_kws={"size":15},vmax=0.6)
plt.show()

# %%
#Anything below 0.5 are good picks, low correlation, less risk per industry

# %%
ticker = ["SPY", "AAPL","KO", "NVDA","AMD","CELH","TSLA", "GOEV","CPNG","TSM","AMZN","CCEP","IONQ"]

# %%
stocks = yf.download(ticker, start = "2021-01-01", end = "2023-12-07")

# %%
close = stocks.loc[:,"Close"].copy()

# %%
normClose=close.div(close.iloc[0]).mul(100)

# %%
normClose.plot(figsize=(15,8), fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
ret= close.pct_change().dropna()
ret.head()

# %%
summary = ret.describe().T.loc[:,["mean","std"]]
summary

# %%
summary["mean"] = summary["mean"]*252
summary["std"] = summary["std"]*np.sqrt(252)
summary

# %%
summary.plot.scatter(x = "std", y = "mean", figsize= (12,8),s=50, fontsize=15)
for i in summary.index:
    plt.annotate(i,xy=(summary.loc[i,"std"]+0.002,summary.loc[i,"mean"]+0.002),size=15)
plt.xlabel("Annual risk(std)", fontsize=15)
plt.ylabel("Annual return", fontsize=15)
plt.title("Risk/Return",fontsize=25)
plt.show

# %%
ret.cov()

# %%
ret.corr()

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.4)
sns.heatmap(ret.corr(),cmap="Reds",annot=True,annot_kws={"size":15},vmax=0.6)
plt.show()

# %%
df = pd.DataFrame(index=[2016,2017,2018], data=[100,50,95], columns=["Price"])

# %%
df

# %%
simplereturns = df.pct_change().dropna()
simplereturns

# %%
simplereturns.mean()

# %%
#Mean returns are misleading as crazy

# %%
logreturns = np.log(df/df.shift(1)).dropna()

# %%
logreturns.mean()

# %%
100*np.exp(logreturns.mean()*2)

# %%
#log returns are more important than simple

# %%
NVIDIA = yf.download("NVDA")

# %%
nvda= NVIDIA.Close.to_frame()

# %%
nvda

# %%
nvda.plot(figsize=(12,8),fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show()

# %%
nvda_roll = nvda.rolling(window=10)

# %%
nvda_roll = nvda_roll.mean()

# %%
nvda_roll.head(15)

# %%
nvda.rolling(window=10).median()

# %%
nvda.rolling(window=10).max()

# %%
nvda.rolling(window=10, min_periods=5).max().head(15)

# %%
nvda

# %%
nvda["SMA50"]=nvda.rolling(window=50, min_periods=50).mean()

# %%
nvda

# %%
nvda.plot(figsize=(12,8),fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show()

# %%
nvda["SMA200"]=nvda.Close.rolling(window=200, min_periods=200).mean()

# %%
nvda.plot(figsize=(12,8),fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show()

# %%
IONQ = yf.download("IONQ")
AMD = yf.download("AMD")
AAPL = yf.download("AAPL")
CELH = yf.download("CELH")

# %%
ionq = IONQ.Close.to_frame()
amd = AMD.Close.to_frame()
aapl= AAPL.Close.to_frame()
celh= CELH.Close.to_frame()

# %%
ionq_roll = ionq.rolling(window=10)
ionq_roll = ionq_roll.mean()
amd_roll = amd.rolling(window=10)
amd_roll = amd_roll.mean()
aapl_roll = aapl.rolling(window=10)
aapl_roll = aapl_roll.mean()
celh_roll = celh.rolling(window=10)
celh_roll = celh_roll.mean()

# %%
ionq.rolling(window=10, min_periods=5).max().head(15)
ionq["SMA50"]=ionq.Close.rolling(window=50, min_periods=50).mean()
ionq["SMA200"]=ionq.Close.rolling(window=200, min_periods=200).mean()

# %%
amd.rolling(window=10, min_periods=5).max().head(15)
amd["SMA50"]=amd.Close.rolling(window=50, min_periods=50).mean()
amd["SMA200"]=amd.Close.rolling(window=200, min_periods=200).mean()

# %%
aapl.rolling(window=10, min_periods=5).max().head(15)
aapl["SMA50"]=aapl.Close.rolling(window=50, min_periods=50).mean()
aapl["SMA200"]=aapl.Close.rolling(window=200, min_periods=200).mean()

# %%
celh.rolling(window=10, min_periods=5).max().head(15)
celh["SMA50"]=celh.Close.rolling(window=50, min_periods=50).mean()
celh["SMA200"]=celh.Close.rolling(window=200, min_periods=200).mean()

# %%
ionq.plot(figsize=(12,8),fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show()

# %%
amd.plot(figsize=(12,8),fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show()

# %%
aapl.plot(figsize=(12,8),fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show()

# %%
celh.plot(figsize=(12,8),fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show()

# %%
nvda["EMA100"]=nvda.Close.ewm(span=100,min_periods=100).mean()

# %%
nvda.plot(figsize=(12,8),fontsize=15)
plt.legend(loc="upper left", fontsize=15)
plt.show()

# %%
nvda["Day"] = nvda.index.day_name()

# %%
nvda["Quarter"] = nvda.index.quarter

# %%
NVDA = yf.download("NVDA")

# %%
NVDA

# %%
nvda= yf.download("NVDA")

# %%
nvda=nvda.Close.to_frame()

# %%
all_days=pd.date_range(start="2010-01-01", end="2023-12-07",freq="D")
all_days

# %%
nvda

# %%
nvda=nvda.reindex(all_days)
nvda

# %%
nvda.fillna(method="ffill")

# %%
nvda.fillna(method="bfill")

# %%
NVDA= yf.download("NVDA", interval="1wk")
NVDA

# %%
##Cummulative Returns, Drawdowns, etc...

# %%
celh = yf.download("CELH")
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
celh = celh.Close.to_frame()

# %%
celh
# Out:
#                 Close
# Date
# 2007-01-22  13.333333
# 2007-01-23  10.600000
# 2007-01-24  11.933333
# 2007-01-25  13.333333
# 2007-01-26  12.733333
# ...               ...
# 2023-12-11  49.689999
# 2023-12-12  49.130001
# 2023-12-13  51.889999
# 2023-12-14  50.900002
# 2023-12-15  49.509998
#
# [4257 rows x 1 columns]

# %%
celh.Close
# Out:
# Date
# 2007-01-23    10.600000
# 2007-01-24    11.933333
# 2007-01-25    13.333333
# 2007-01-26    12.733333
# 2007-01-29    16.000000
#                 ...
# 2023-12-11    49.689999
# 2023-12-12    49.130001
# 2023-12-13    51.889999
# 2023-12-14    50.900002
# 2023-12-15    49.509998
# Name: Close, Length: 4256, dtype: float64

# %%
celh["d_returns"] = np.log(celh.div(celh.shift(1)))

# %%
celh
# Out:
#                 Close  d_returns
# Date
# 2007-01-22  13.333333        NaN
# 2007-01-23  10.600000  -0.229413
# 2007-01-24  11.933333   0.118482
# 2007-01-25  13.333333   0.110932
# 2007-01-26  12.733333  -0.046044
# ...               ...        ...
# 2023-12-11  49.689999  -0.024059
# 2023-12-12  49.130001  -0.011334
# 2023-12-13  51.889999   0.054656
# 2023-12-14  50.900002  -0.019263
# 2023-12-15  49.509998  -0.027688
#
# [4257 rows x 2 columns]

# %%
celh.dropna(inplace=True)

# %%
celh
# Out:
#                 Close  d_returns
# Date
# 2007-01-23  10.600000  -0.229413
# 2007-01-24  11.933333   0.118482
# 2007-01-25  13.333333   0.110932
# 2007-01-26  12.733333  -0.046044
# 2007-01-29  16.000000   0.228366
# ...               ...        ...
# 2023-12-11  49.689999  -0.024059
# 2023-12-12  49.130001  -0.011334
# 2023-12-13  51.889999   0.054656
# 2023-12-14  50.900002  -0.019263
# 2023-12-15  49.509998  -0.027688
#
# [4256 rows x 2 columns]

# %%
celh.d_returns.sum()
# Out:
# 1.31190749386779

# %%
np.exp(celh.d_returns.sum())
# Out:
# 3.713249962645763

# %%
celh["CummReturns"]=celh.d_returns.cumsum().apply(np.exp)

# %%
celh
# Out:
#                 Close  d_returns  CummReturns
# Date
# 2007-01-23  10.600000  -0.229413      0.79500
# 2007-01-24  11.933333   0.118482      0.89500
# 2007-01-25  13.333333   0.110932      1.00000
# 2007-01-26  12.733333  -0.046044      0.95500
# 2007-01-29  16.000000   0.228366      1.20000
# ...               ...        ...          ...
# 2023-12-11  49.689999  -0.024059      3.72675
# 2023-12-12  49.130001  -0.011334      3.68475
# 2023-12-13  51.889999   0.054656      3.89175
# 2023-12-14  50.900002  -0.019263      3.81750
# 2023-12-15  49.509998  -0.027688      3.71325
#
# [4256 rows x 3 columns]

# %%
celh.CummReturns.plot(figsize=(12,8),title="CELH Buy & Hold",fontsize=12)
# Out:
# <Axes: title={'center': 'CELH Buy & Hold'}, xlabel='Date'>

# %%
celh.d_returns.mean()*252
# Out:
# 0.07767873318954019

# %%
celh.d_returns.std()*np.sqrt(252)
# Out:
# 1.2859795272042864

# %%
##How to calc drawdowns

# %%
celh["CummMax"]=celh.CummReturns.cummax()

# %%
celh[["CummReturns","CummMax"]].plot(figsize=(12,8),title="CELH Buy & Hold + CummMax",fontsize=12)
# Out:
# <Axes: title={'center': 'CELH Buy & Hold + CummMax'}, xlabel='Date'>

# %%
celh["Drawdown"]=celh["CummMax"]-celh["CummReturns"]
celh
# Out:
#                 Close  d_returns  CummReturns  CummMax  Drawdown
# Date
# 2007-01-23  10.600000  -0.229413      0.79500   0.7950   0.00000
# 2007-01-24  11.933333   0.118482      0.89500   0.8950   0.00000
# 2007-01-25  13.333333   0.110932      1.00000   1.0000   0.00000
# 2007-01-26  12.733333  -0.046044      0.95500   1.0000   0.04500
# 2007-01-29  16.000000   0.228366      1.20000   1.2000   0.00000
# ...               ...        ...          ...      ...       ...
# 2023-12-11  49.689999  -0.024059      3.72675   5.1315   1.40475
# 2023-12-12  49.130001  -0.011334      3.68475   5.1315   1.44675
# 2023-12-13  51.889999   0.054656      3.89175   5.1315   1.23975
# 2023-12-14  50.900002  -0.019263      3.81750   5.1315   1.31400
# 2023-12-15  49.509998  -0.027688      3.71325   5.1315   1.41825
#
# [4256 rows x 5 columns]

# %%
celh.Drawdown.max()
# Out:
# 1.821249947998672

# %%
celh.Drawdown.idxmax()
# Out:
# Timestamp('2011-10-06 00:00:00')

# %%
celh.loc[(celh.index<='2011-10-06')]
# Out:
#                 Close  d_returns  CummReturns  CummMax  Drawdown
# Date
# 2007-01-23  10.600000  -0.229413      0.79500    0.795   0.00000
# 2007-01-24  11.933333   0.118482      0.89500    0.895   0.00000
# 2007-01-25  13.333333   0.110932      1.00000    1.000   0.00000
# 2007-01-26  12.733333  -0.046044      0.95500    1.000   0.04500
# 2007-01-29  16.000000   0.228366      1.20000    1.200   0.00000
# ...               ...        ...          ...      ...       ...
# 2011-09-30   0.060000  -0.510826      0.00450    1.825   1.82050
# 2011-10-03   0.066667   0.105366      0.00500    1.825   1.82000
# 2011-10-04   0.093333   0.336464      0.00700    1.825   1.81800
# 2011-10-05   0.056667  -0.498982      0.00425    1.825   1.82075
# 2011-10-06   0.050000  -0.125169      0.00375    1.825   1.82125
#
# [1188 rows x 5 columns]

# %%
celh["Drawdown%"] = (celh["CummMax"]-celh["CummReturns"])/celh["CummMax"]

# %%
celh

# %%
celh["Drawdown%"].max()
# Out:
# 0.9979452053414576

# %%
celh["Drawdown%"].idxmax()
# Out:
# Timestamp('2011-10-06 00:00:00')

# %%
celh.loc[(celh.index<='2011-10-06')]
# Out:
#                 Close  d_returns  CummReturns  CummMax  Drawdown  Drawdown%
# Date
# 2007-01-23  10.600000  -0.229413      0.79500    0.795   0.00000   0.000000
# 2007-01-24  11.933333   0.118482      0.89500    0.895   0.00000   0.000000
# 2007-01-25  13.333333   0.110932      1.00000    1.000   0.00000   0.000000
# 2007-01-26  12.733333  -0.046044      0.95500    1.000   0.04500   0.045000
# 2007-01-29  16.000000   0.228366      1.20000    1.200   0.00000   0.000000
# ...               ...        ...          ...      ...       ...        ...
# 2011-09-30   0.060000  -0.510826      0.00450    1.825   1.82050   0.997534
# 2011-10-03   0.066667   0.105366      0.00500    1.825   1.82000   0.997260
# 2011-10-04   0.093333   0.336464      0.00700    1.825   1.81800   0.996164
# 2011-10-05   0.056667  -0.498982      0.00425    1.825   1.82075   0.997671
# 2011-10-06   0.050000  -0.125169      0.00375    1.825   1.82125   0.997945
#
# [1188 rows x 6 columns]

# %%
##SMA Strategy

# %%
data = celh.Close.loc[(celh.index>='2011-10-06')

# %%
data=data.to_frame()

# %%
data

# %%
sma_s=50
sma_l=100

# %%
data["SMA_S"]=data.Close.rolling(sma_s).mean()
data["SMA_L"]=data.Close.rolling(sma_l).mean()

# %%
data

# %%
data.plot(figsize=(12,8),title="CELH - SMA{} | SMA{}".format(sma_s,sma_l),fontsize=12)

# %%
data.loc["2023"].plot(figsize=(12,8),title="CELH - SMA{} | SMA{}".format(sma_s,sma_l),fontsize=12)

# %%
data.dropna(inplace=True)

# %%
data

# %%
data["Position"]=np.where(data["SMA_S"]>data["SMA_L"],1,-1)
data

# %%
data.loc["2023",["SMA_S","SMA_L","Position"]].plot(figsize=(12,8),title="CELH - SMA{} | SMA{}".format(sma_s,sma_l),fontsize=12,secondary_y="Position")

# %%
data["ReturnsB&H"]=np.log(data.Close.div(data.Close.shift(1)))

# %%
data["Strategy"]=data["ReturnsB&H"]*data.Position.shift(1)

# %%
data

# %%
data.dropna(inplace=True)

# %%
data[["ReturnsB&H", "Strategy"]].sum()

# %%
data[["ReturnsB&H", "Strategy"]].sum().apply(np.exp) #what 1 dollar will be

# %%
data[["ReturnsB&H", "Strategy"]].std()*np.sqrt(252) #Annual std

# %%
data.Close.plot(figsize=(12,8))

# %%
## Strat Adjusted for Long Bias

# %%
data["Position2"]=np.where(data["SMA_S"]>data["SMA_L"],1,0)

# %%
data["Strategy2"]=data["ReturnsB&H"]*data.Position2.shift(1)
data.dropna(inplace=True)

# %%
data[["ReturnsB&H", "Strategy2"]].sum()

# %%
data[["ReturnsB&H", "Strategy2"]].sum().apply(np.exp) #what 1 dollar will be

# %%
data[["ReturnsB&H", "Strategy2"]].std()*np.sqrt(252) #Annual std

# %%
##Strategy2 is better than Strategy1
compare=data[["Strategy", "Strategy2"]].std()*np.sqrt(252)

# %%
##Lower STD and possible Drawdowns
##Excercise 3: Take the 5 previous stocks ans create a bias strategy, compare drawdowns
##Pick the best 3 stocks in your portfolio

# %%
data.loc["2023",["Strategy","Strategy2","Position"]].plot(figsize=(12,8),title="CELH Strategy Comparison".format("Strategy","Strategy2"),fontsize=12,secondary_y="Position")

# %%
nvda=yf.download("NVDA")
vac= yf.download("VAC")
aapl = yf.download("AAPL")
ionq = yf.download("IONQ")

# %%
data1 = nvda.loc[(nvda.index>='2016-01-01')]
data2 = vac.loc[(vac.index>='2021-01-01')]
data3 = aapl.loc[(aapl.index>='2021-01-01')]
data4 = ionq.loc[(ionq.index>='2021-01-01')]

# %%
data1=data1.Close.to_frame()
data2=data2.Close.to_frame()
data3=data3.Close.to_frame()
data4=data4.Close.to_frame()
data2

# %%
sma_s=50
sma_l=100

# %%
data1["SMA_S"]=data1.Close.rolling(sma_s).mean()
data1["SMA_L"]=data1.Close.rolling(sma_l).mean()
data2["SMA_S"]=data2.Close.rolling(sma_s).mean()
data2["SMA_L"]=data2.Close.rolling(sma_l).mean()
data3["SMA_S"]=data3.Close.rolling(sma_s).mean()
data3["SMA_L"]=data3.Close.rolling(sma_l).mean()
data4["SMA_S"]=data4.Close.rolling(sma_s).mean()
data4["SMA_L"]=data4.Close.rolling(sma_l).mean()
data2

# %%
data1.plot(figsize=(12,8),title="NVDA - SMA{} | SMA{}".format(sma_s,sma_l),fontsize=12)
data2.plot(figsize=(12,8),title="VAC - SMA{} | SMA{}".format(sma_s,sma_l),fontsize=12)
data3.plot(figsize=(12,8),title="AAPL - SMA{} | SMA{}".format(sma_s,sma_l),fontsize=12)
data4.plot(figsize=(12,8),title="IONQ - SMA{} | SMA{}".format(sma_s,sma_l),fontsize=12)

# %%
data1.loc["2023"].plot(figsize=(12,8),title="NVDA - SMA{} | SMA{}".format(sma_s,sma_l),fontsize=12)
data2.loc["2023"].plot(figsize=(12,8),title="VAC SMA{} | SMA{}".format(sma_s,sma_l),fontsize=12)
data3.loc["2023"].plot(figsize=(12,8),title="AAPL - SMA{} | SMA{}".format(sma_s,sma_l),fontsize=12)
data4.loc["2023"].plot(figsize=(12,8),title="IONQ - SMA{} | SMA{}".format(sma_s,sma_l),fontsize=12)

# %%
data1["ReturnsB&H"]=np.log(data1.Close.div(data1.Close.shift(1)))
data2["ReturnsB&H"]=np.log(data2.Close.div(data2.Close.shift(1)))
data3["ReturnsB&H"]=np.log(data3.Close.div(data3.Close.shift(1)))
data4["ReturnsB&H"]=np.log(data4.Close.div(data4.Close.shift(1)))

# %%
data1["Position"]=np.where(data1["SMA_S"]>data1["SMA_L"],1,-1)
data2["Position"]=np.where(data2["SMA_S"]>data2["SMA_L"],1,-1)
data3["Position"]=np.where(data3["SMA_S"]>data3["SMA_L"],1,-1)
data4["Position"]=np.where(data4["SMA_S"]>data4["SMA_L"],1,-1)

# %%
data1["Strategy"]=data1["ReturnsB&H"]*data1.Position.shift(1)
data2["Strategy"]=data2["ReturnsB&H"]*data2.Position.shift(1)
data3["Strategy"]=data3["ReturnsB&H"]*data3.Position.shift(1)
data4["Strategy"]=data3["ReturnsB&H"]*data4.Position.shift(1)

# %%
data2

# %%
data1.dropna(inplace=True)
data2.dropna(inplace=True)
data3.dropna(inplace=True)
data4.dropna(inplace=True)

# %%
data2

# %%
##data1[["ReturnsB&H", "Strategy"]].sum()
data2[["ReturnsB&H", "Strategy"]].sum()
##data3[["ReturnsB&H", "Strategy"]].sum()
##data4[["ReturnsB&H", "Strategy"]].sum()

# %%
#data1[["ReturnsB&H", "Strategy"]].sum().apply(np.exp)#what 1 dollar will be
data2[["ReturnsB&H", "Strategy"]].sum().apply(np.exp)
#data3[["ReturnsB&H", "Strategy"]].sum().apply(np.exp)
#data4[["ReturnsB&H", "Strategy"]].sum().apply(np.exp)

# %%
data1[["ReturnsB&H", "Strategy"]].std()*np.sqrt(252) #Annual std
data2[["ReturnsB&H", "Strategy"]].std()*np.sqrt(252) #Annual std
data3[["ReturnsB&H", "Strategy"]].std()*np.sqrt(252) #Annual std
data3[["ReturnsB&H", "Strategy"]].std()*np.sqrt(252) #Annual std

# %%
#data1.Close.plot(figsize=(12,8))
data2.Close.plot(figsize=(12,8),title="VAC 3 Year Analysis",fontsize=12)
#data3.Close.plot(figsize=(12,8))
#data4.Close.plot(figsize=(12,8))

# %%
data1["Position2"]=np.where(data1["SMA_S"]>data1["SMA_L"],1,0)
data2["Position2"]=np.where(data2["SMA_S"]>data2["SMA_L"],1,0)
data3["Position2"]=np.where(data3["SMA_S"]>data3["SMA_L"],1,0)
data4["Position2"]=np.where(data4["SMA_S"]>data4["SMA_L"],1,0)

# %%
data1["Strategy2"]=data1["ReturnsB&H"]*data1.Position2.shift(1)
data1.dropna(inplace=True)
data2["Strategy2"]=data2["ReturnsB&H"]*data2.Position2.shift(1)
data2.dropna(inplace=True)
data3["Strategy2"]=data3["ReturnsB&H"]*data3.Position2.shift(1)
data3.dropna(inplace=True)
data4["Strategy2"]=data4["ReturnsB&H"]*data4.Position2.shift(1)
data4.dropna(inplace=True)

# %%
data1[["ReturnsB&H", "Strategy2"]].sum()
data2[["ReturnsB&H", "Strategy2"]].sum()
data3[["ReturnsB&H", "Strategy2"]].sum()
data4[["ReturnsB&H", "Strategy2"]].sum()

# %%
data1[["ReturnsB&H", "Strategy2"]].sum().apply(np.exp) #what 1 dollar will be
data2[["ReturnsB&H", "Strategy2"]].sum().apply(np.exp) 
data3[["ReturnsB&H", "Strategy2"]].sum().apply(np.exp) 
data4[["ReturnsB&H", "Strategy2"]].sum().apply(np.exp)

# %%
data1[["ReturnsB&H", "Strategy2"]].std()*np.sqrt(252) #Annual std
data2[["ReturnsB&H", "Strategy2"]].std()*np.sqrt(252)
data3[["ReturnsB&H", "Strategy2"]].std()*np.sqrt(252)
data4[["ReturnsB&H", "Strategy2"]].std()*np.sqrt(252)

# %%
compare=data1[["Strategy", "Strategy2"]].std()*np.sqrt(252)
compare2=data2[["Strategy", "Strategy2"]].std()*np.sqrt(252)
compare3=data3[["Strategy", "Strategy2"]].std()*np.sqrt(252)
compare4=data4[["Strategy", "Strategy2"]].std()*np.sqrt(252)

# %%
#compare
compare2
#compare3
#compare4

# %%
#data1.loc["2023",["Strategy","Strategy2","Position"]].plot(figsize=(12,8),title="NVDA Strategy Comparison".format("Strategy","Strategy2"),fontsize=12,secondary_y="Position")
data2.plot(figsize=(12,8),title="VAC Strategy Comparison".format("Strategy","Strategy2"),fontsize=12,secondary_y="Position")
data2.loc["2023",["Strategy","Strategy2","Position"]].plot(figsize=(12,8),title="VAC Strategy Comparison".format("Strategy","Strategy2"),fontsize=12,secondary_y="Position")
#data3.loc["2023",["Strategy","Strategy2","Position"]].plot(figsize=(12,8),title="AAPL Strategy Comparison".format("Strategy","Strategy2"),fontsize=12,secondary_y="Position")
#data4.loc["2023",["Strategy","Strategy2","Position"]].plot(figsize=(12,8),title="IONQ Strategy Comparison".format("Strategy","Strategy2"),fontsize=12,secondary_y="Position")

# %%
cart = yf.download("CART")
cart.Close

# %%
cart.plot(figsize=(12,8),title="CART Close",fontsize = 12)

# %%
cart.Close.to_frame()

# %%
data =cart.loc[(cart.index>='2023-01-01')]

# %%
data["SMA_S"]=data.Close.rolling(sma_s).mean()
data["SMA_L"]=data.Close.rolling(sma_l).mean()

# %%
data.plot(figsize=(12,8),title="CART - SMA{} | SMA{}".format(sma_s,sma_l),fontsize=12)

# %%
data["Position"]=np.where(data["SMA_S"]>data["SMA_L"],1,-1)
data["ReturnsB&H"]=np.log(data.Close.div(data.Close.shift(1)))
data["Strategy"]=data["ReturnsB&H"]*data.Position.shift(1)

# %%
data.dropna(inplace=True)
data[["ReturnsB&H", "Strategy"]].sum()

# %%
## Creating our first function

# %%
def test_strat(stock,start,end,SMA):
    df = yf.download(stock,start=start,end=end)
    data= df.Close.to_frame()
    data["Returns"]=np.log(data.Close.div(data.Close.shift(1)))
    data["SMA_S"]=data.Close.rolling(int(SMA[0])).mean()
    data["SMA_L"]=data.Close.rolling(int(SMA[1])).mean()
    data.dropna(inplace=True)
    
    data["Position"]=np.where(data["SMA_S"]>data["SMA_L"],1,-1)##(1,-1)==Long
    data["Strategy"]=data["Returns"]*data.Position.shift(1)
    data.dropna(inplace=True)
    ret=np.exp(data["Strategy"].sum())
    std=data["Strategy"].std()*np.sqrt(252)
    return ret, std

# %%
test_strat("KO","2022-01-01","2023-12-08",(20,200))

# %%
##First Class

# %%
class SMABacktester():
    def __init__(self,symbol,SMA_S,SMA_L,start,end):
        self.symbol=symbol
        self.SMA_S=SMA_S
        self.SMA_L=SMA_L
        self.start=start
        self.end=end
        self.results=None
        self.get_data()
        
    def get_data(self):
        df = yf.download(self.symbol,start=self.start,end=self.end)
        data= df.Close.to_frame()
        data["Returns"]=np.log(data.Close.div(data.Close.shift(1)))
        data["SMA_S"]=data.Close.rolling(int(self.SMA_S)).mean()
        data["SMA_L"]=data.Close.rolling(int(self.SMA_L)).mean()
        data.dropna(inplace=True)
        self.data2=data
        
        return data
    
    def test_results(self):
        data=self.data2.copy().dropna()
        data["Position"]=np.where(data["SMA_S"]>data["SMA_L"],1,-1)
        data["Strategy"]=data["Returns"]*data.Position.shift(1)
        data.dropna(inplace=True)
        data["Returnsbh"]=data["Returns"].cumsum().apply(np.exp)
        data["ReturnsStrategy"]=data["Strategy"].cumsum().apply(np.exp)
        perf=data["ReturnsStrategy"].iloc[-1]
        outperf=perf-data["Returnsbh"].iloc[-1]
        self.results=data
        
        ret=np.exp(data["Strategy"].sum())
        std=data["Strategy"].std()*np.sqrt(252)
        #return ret,std
            
        return round(perf,6), round(outperf,6)
    
    def plot_results(self):
        if self.results is None:
            print("Run the test please:)")
        else:
            title="{} SMA_S={} | SMA_L={}".format(self.symbol,self.SMA_S,self.SMA_L)
            self.results[["Returnsbh","ReturnsStrategy"]].plot(title=title, figsize=(12,8))

# %%
tester=SMABacktester("NVDA",50,100,"2019-01-01","2023-12-08")

# %%
tester.test_results()

# %%
tester.plot_results()

# %%
##API: It's like talking to another person, asking for a beer, and receiving a beer

# %%
from alpha_vantage.timeseries import TimeSeries

# %%
API_key="R6MZ92WJR3IZK1S8"

# %%
ts=TimeSeries(key=API_key,output_format='pandas')

# %%
data=ts.get_daily('VAC')

# %%
data

# %%
data[0]

# %%
data2=data[0]

# %%
data2

# %%
data2.columns

# %%
data2["5. volume"]
